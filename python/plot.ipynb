# %%
import matplotlib.pyplot as plt
import pandas as pd
import sqlite3

# %matplotlib inline

# %%
df = pd.read_csv("/Users/DV79FN/Git/league-of-legends/python/participant_frames.csv")
df.head(5)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pos_x</th>
#       <th>pos_y</th>
#       <th>win</th>
#       <th>creepScore</th>
#       <th>currentGold</th>
#       <th>dominionScore</th>
#       <th>experience</th>
#       <th>goldEarned</th>
#       <th>level</th>
#       <th>neutralMinionsKilled</th>
#       <th>participantId</th>
#       <th>teamScore</th>
#       <th>timestamp</th>
#       <th>summoner</th>
#       <th>match_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1102</td>
#       <td>1180</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1400</td>
#       <td>0</td>
#       <td>660</td>
# ...

# %%
df.count()
# Out:
# pos_x                   19755
# pos_y                   19755
# win                     19755
# creepScore              19755
# currentGold             19755
# dominionScore           19755
# experience              19755
# goldEarned              19755
# level                   19755
# neutralMinionsKilled    19755
# participantId           19755
# teamScore               19755
# timestamp               19755
# summoner                19755
# match_id                19755
# dtype: int64

# %%
df.dtypes
# Out:
# pos_x                     int64
# pos_y                     int64
# win                       int64
# creepScore                int64
# currentGold               int64
# dominionScore             int64
# experience                int64
# goldEarned                int64
# level                     int64
# neutralMinionsKilled      int64
# participantId             int64
# teamScore                 int64
# timestamp               float64
# summoner                 object
# match_id                  int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        pos_x  pos_y  win  creepScore  currentGold  dominionScore  experience  \
# 0       1102   1180    0           0         1400              0         660
# 1       1102    960    0           0         1400              0         660
# 2        893    892    0           0         1400              0         660
# 3        763   1070    0           0         1400              0         660
# 4        853   1248    0           0         1400              0         660
# 5      12006  11716    1           0         1400              0         660
# 6      12006  11496    1           0         1400              0         660
# 7      11797  11428    1           0         1400              0         660
# 8      11667  11606    1           0         1400              0         660
# 9       5699   5685    0           0            0              0         957
# 10      5956   5576    0           0           15              0         957
# ...

# %%
df.cov
# Out:
# <bound method DataFrame.cov of        pos_x  pos_y  win  creepScore  currentGold  dominionScore  experience  \
# 0       1102   1180    0           0         1400              0         660
# 1       1102    960    0           0         1400              0         660
# 2        893    892    0           0         1400              0         660
# 3        763   1070    0           0         1400              0         660
# 4        853   1248    0           0         1400              0         660
# 5      12006  11716    1           0         1400              0         660
# 6      12006  11496    1           0         1400              0         660
# 7      11797  11428    1           0         1400              0         660
# 8      11667  11606    1           0         1400              0         660
# 9       5699   5685    0           0            0              0         957
# 10      5956   5576    0           0           15              0         957
# ...

# %%
plt.figure(figsize=(15, 7))
plt.plot(pframe.currentGold)
plt.title('Ads watched (hourly data)')
plt.grid(True)
plt.show()

# %%
pframe.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>pos_x</th>
#       <th>pos_y</th>
#       <th>win</th>
#       <th>creepScore</th>
#       <th>currentGold</th>
#       <th>dominionScore</th>
#       <th>experience</th>
#       <th>goldEarned</th>
#       <th>level</th>
#       <th>neutralMinionsKilled</th>
#       <th>participantId</th>
#       <th>teamScore</th>
#       <th>timestamp</th>
#       <th>summoner</th>
#       <th>match_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>1102</td>
#       <td>1180</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1400</td>
#       <td>0</td>
#       <td>660</td>
# ...
